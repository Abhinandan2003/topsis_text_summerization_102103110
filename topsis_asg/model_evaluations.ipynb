# %%
pip install Topsis-Abhinandan-102103110==0.0.1
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Abhinandan Sharma\\Desktop\\topsis_asg\\evaluation_result.csv")

# %%
df.head(6)
# Out:
#                            Model  Semantic Coherence  Factual Accuracy  \
# 0        facebook/bart-large-cnn            0.655736          0.458349
# 1                       t5-large            0.755254          0.457265
# 2  sshleifer/distilbart-cnn-12-6            0.707827          0.521906
# 3           google/pegasus-large            0.706821          0.420956
# 4  allenai/led-large-16384-arxiv            0.192766          0.288377
# 5     sshleifer/bart-tiny-random            0.001195          0.001887
#
#    Content Coverage    Fluency
# 0          0.371619  13.824154
# 1          0.408908  15.828586
# 2          0.484382  15.687915
# 3          0.364452  11.779998
# 4          0.190282   4.300495
# 5          0.002203   1.110978

# %%
# !topsis evaluation_result.csv "1,1,1,1" "+,+,+,+"  output.csv
# Out:
# Topsis
# TOPSIS analysis completed. Output saved to output.csv

# %%
op =  pd.read_csv("C:\\Users\\Abhinandan Sharma\\Desktop\\topsis_asg\\output.csv")
op.head(6)
# Out:
#                            Model  Semantic Coherence  Factual Accuracy  \
# 0        facebook/bart-large-cnn            0.655736          0.458349
# 1                       t5-large            0.755254          0.457265
# 2  sshleifer/distilbart-cnn-12-6            0.707827          0.521906
# 3           google/pegasus-large            0.706821          0.420956
# 4  allenai/led-large-16384-arxiv            0.192766          0.288377
# 5     sshleifer/bart-tiny-random            0.001195          0.001887
#
#    Content Coverage    Fluency  Topsis Score  Rank
# 0          0.371619  13.824154      0.165124   4.0
# 1          0.408908  15.828586      0.100919   5.0
# 2          0.484382  15.687915      0.030906   6.0
# 3          0.364452  11.779998      0.207833   3.0
# 4          0.190282   4.300495      0.632364   2.0
# 5          0.002203   1.110978      1.000000   1.0

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
plt.bar(op["Model"], op["Topsis Score"], color='red')
plt.xlabel("Model")
plt.ylabel("TOPSIS Score")
plt.title("TOPSIS Score of Each Model")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
